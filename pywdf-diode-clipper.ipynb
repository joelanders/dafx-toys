# %%
# %pip install git+https://github.com/gusanthon/pywdf
# Out:
# Collecting git+https://github.com/gusanthon/pywdf
#   Cloning https://github.com/gusanthon/pywdf to /tmp/pip-req-build-tcy87mqa
#   Running command git clone --filter=blob:none --quiet https://github.com/gusanthon/pywdf /tmp/pip-req-build-tcy87mqa
#   Resolved https://github.com/gusanthon/pywdf to commit f4c1df0bb9d245c26db68c339bb84ad211dafd44
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pywdf
#   Building wheel for pywdf (setup.py) ... done
#   Created wheel for pywdf: filename=pywdf-0.0.1-py3-none-any.whl size=29772 sha256=fc6d724b9a63db531bcb7e6b1dbe66704fd1ab644f81bbb87640d6819f7c4b16
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lj7111rb/wheels/92/02/cf/bd065771ab21e795705b0a8c8beba3b8ade150bf141b02ab80
# Successfully built pywdf
# Installing collected packages: pywdf
# Successfully installed pywdf-0.0.1

# %%
from pywdf import DiodeClipper

# from pywdf readme
dc = DiodeClipper(44100, cutoff= 1000, input_gain_db = 5)
dc.AC_transient_analysis()
